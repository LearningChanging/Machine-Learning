# %% [markdown]
# # 机器学习入门-线性回归预测温度
# 温度随海拔变化
# y = ax + b

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('exercise/height.vs.temperature.csv')

# %%
data.head()
# Out:
#    height  temperature
# 0     0.0    12.834044
# 1   500.0    10.190649
# 2  1000.0     5.500229
# 3  1500.0     2.854665
# 4  2000.0    -0.706488

# %%
data.columns
# Out:
# Index(['height', 'temperature'], dtype='object')

# %% [markdown]
# ## 通过数据可视化分析数据

# %%
plt.figure(figsize=(16, 8))
plt.scatter(data['height'], data['temperature'], c ='black')
plt.xlabel("temperature spent on height")
plt.ylabel("temperature")
plt.show()

# %% [markdown]
# ## 训练线性回归模型

# %%
X = data['height'].values.reshape(-1,1)
y = data['temperature'].values.reshape(-1,1)

reg = LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('a = {:.5}'.format(reg.coef_[0][0]))
print('b = {:.5}'.format(reg.intercept_[0]))

print("线性模型为: Y = {:.5}X + {:.5} ".format(reg.coef_[0][0], reg.intercept_[0]))
# Out:
# a = -0.0065695
# b = 12.719
# 线性模型为: Y = -0.0065695X + 12.719

# %% [markdown]
# ## 可视化训练好的线性回归模型

# %%
predictions = reg.predict(X)

plt.figure(figsize=(16, 8))
plt.scatter(data['height'], data['temperature'], c ='black')
plt.plot(data['height'], predictions,c ='blue', linewidth=2)
plt.xlabel("temperature spent on height")
plt.ylabel("temperature")
plt.show()

# %% [markdown]
# # 做预测
# 在海拔5000米的地方温度是多少？

# %%
predictions = reg.predict([[5000]])
print('在海拔5000米的地方温度为{:.3}℃'.format( predictions[0][0]) )
# Out:
# 在海拔5000米的地方温度为-20.1℃
